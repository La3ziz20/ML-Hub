# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("car data.csv")
df.head()
# Out:
#          ID  Price  Levy Manufacturer    Model  Prod. year   Category  \
# 0  45654403  13328  1399        LEXUS   RX 450        2010       Jeep
# 1  44731507  16621  1018    CHEVROLET  Equinox        2011       Jeep
# 2  45774419   8467     -        HONDA      FIT        2006  Hatchback
# 3  45769185   3607   862         FORD   Escape        2011       Jeep
# 4  45809263  11726   446        HONDA      FIT        2014  Hatchback
#
#   Leather interior Fuel type Engine volume    Mileage  Cylinders  \
# 0              Yes    Hybrid           3.5  186005 km        6.0
# 1               No    Petrol             3  192000 km        6.0
# 2               No    Petrol           1.3  200000 km        4.0
# 3              Yes    Hybrid           2.5  168966 km        4.0
# 4              Yes    Petrol           1.3   91901 km        4.0
#
#   Gear box type Drive wheels   Doors             Wheel   Color  Airbags
# 0     Automatic          4x4  04-May        Left wheel  Silver       12
# ...

# %%
df.shape          
df.columns        
df.info()         
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19237 entries, 0 to 19236
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                19237 non-null  int64
#  1   Price             19237 non-null  int64
#  2   Levy              19237 non-null  object
#  3   Manufacturer      19237 non-null  object
#  4   Model             19237 non-null  object
#  5   Prod. year        19237 non-null  int64
#  6   Category          19237 non-null  object
#  7   Leather interior  19237 non-null  object
#  8   Fuel type         19237 non-null  object
#  9   Engine volume     19237 non-null  object
#  10  Mileage           19237 non-null  object
#  11  Cylinders         19237 non-null  float64
#  12  Gear box type     19237 non-null  object
#  13  Drive wheels      19237 non-null  object
#  14  Doors             19237 non-null  object
#  15  Wheel             19237 non-null  object
# ...

# %%
df.columns = df.columns.str.strip().str.replace(" ", "_")
df.columns
# Out:
# Index(['ID', 'Price', 'Levy', 'Manufacturer', 'Model', 'Prod._year',
#        'Category', 'Leather_interior', 'Fuel_type', 'Engine_volume', 'Mileage',
#        'Cylinders', 'Gear_box_type', 'Drive_wheels', 'Doors', 'Wheel', 'Color',
#        'Airbags'],
#       dtype='object')

# %%
df['Price'] = df['Price'].fillna(df['Price'].mean())

# %%
df.columns = df.columns.str.strip().str.replace(" ", "_")
df.columns
# Out:
# Index(['ID', 'Price', 'Levy', 'Manufacturer', 'Model', 'Prod._year',
#        'Category', 'Leather_interior', 'Fuel_type', 'Engine_volume', 'Mileage',
#        'Cylinders', 'Gear_box_type', 'Drive_wheels', 'Doors', 'Wheel', 'Color',
#        'Airbags'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# ID                  0
# Price               0
# Levy                0
# Manufacturer        0
# Model               0
# Prod._year          0
# Category            0
# Leather_interior    0
# Fuel_type           0
# Engine_volume       0
# Mileage             0
# Cylinders           0
# Gear_box_type       0
# Drive_wheels        0
# Doors               0
# Wheel               0
# Color               0
# Airbags             0
# dtype: int64

# %%
df['Price'] = pd.to_numeric(df['Price'], errors='coerce')
df['Price'].fillna(df['Price'].mean(), inplace=True)
# Out:
# C:\Users\azizm\AppData\Local\Temp\ipykernel_10724\2312305649.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Price'].fillna(df['Price'].mean(), inplace=True)

# %%
df['Mileage'] = df['Mileage'].str.replace(' km', '')
df['Mileage'] = pd.to_numeric(df['Mileage'], errors='coerce')
df['Mileage'].fillna(df['Mileage'].median(), inplace=True)
# Out:
# C:\Users\azizm\AppData\Local\Temp\ipykernel_10724\3605766385.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Mileage'].fillna(df['Mileage'].median(), inplace=True)

# %%
df['Engine_volume'] = df['Engine_volume'].str.extract('(\d+\.\d+)')
df['Engine_volume'] = pd.to_numeric(df['Engine_volume'], errors='coerce')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\azizm\AppData\Local\Temp\ipykernel_10724\2551181765.py:1: SyntaxWarning: invalid escape sequence '\d'
#   df['Engine_volume'] = df['Engine_volume'].str.extract('(\d+\.\d+)')

# %%
df.duplicated().sum()
df.drop_duplicates(inplace=True)

# %%
df['Car_Age'] = 2026 - df['Prod._year']

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18924 entries, 0 to 19236
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                18924 non-null  int64
#  1   Price             18924 non-null  int64
#  2   Levy              18924 non-null  object
#  3   Manufacturer      18924 non-null  object
#  4   Model             18924 non-null  object
#  5   Prod._year        18924 non-null  int64
#  6   Category          18924 non-null  object
#  7   Leather_interior  18924 non-null  object
#  8   Fuel_type         18924 non-null  object
#  9   Engine_volume     13947 non-null  float64
#  10  Mileage           18924 non-null  int64
#  11  Cylinders         18924 non-null  float64
#  12  Gear_box_type     18924 non-null  object
#  13  Drive_wheels      18924 non-null  object
#  14  Doors             18924 non-null  object
#  15  Wheel             18924 non-null  object
# ...

# %%
df['Engine_volume'] = df['Engine_volume'].fillna(df['Engine_volume'].median())

# %%
# Voir les très grandes valeurs
df[df['Mileage'] > 1000000].head()
# Out:
#             ID  Price Levy   Manufacturer   Model  Prod._year   Category  \
# 144   45759786   4300    -  MERCEDES-BENZ     208        1985  Universal
# 493   45781924  15994  777         TOYOTA   Camry        2014      Sedan
# 985   45807165   2700    -           OPEL  Vectra        1997      Sedan
# 1146  44615609  13485    -            BMW     525        2003      Sedan
# 1404  45814878   9095    -            BMW     328        2002      Sedan
#
#      Leather_interior Fuel_type  Engine_volume    Mileage  Cylinders  \
# 144                No    Diesel            2.5    1111111        4.0
# 493                No    Petrol            2.5    1440000        4.0
# 985                No       CNG            1.6  777777777        4.0
# 1146              Yes    Petrol            2.5    7777787        6.0
# 1404               No    Petrol            2.8   55556665        6.0
#
#      Gear_box_type Drive_wheels   Doors       Wheel   Color  Airbags  Car_Age
# ...

# %%
df = df[df['Mileage'] < 1000000]

# %%
q_low = df['Price'].quantile(0.01)
q_high = df['Price'].quantile(0.99)

df = df[(df['Price'] > q_low) & (df['Price'] < q_high)]

# %%
df['Levy'] = df['Levy'].replace('-', np.nan)
df['Levy'] = pd.to_numeric(df['Levy'], errors='coerce')
df['Levy'] = df['Levy'].fillna(df['Levy'].median())

# %%
df['Doors'].unique()
# Out:
# array(['04-May', '02-Mar', '>5'], dtype=object)

# %%
df['Doors'].dtype
# Out:
# dtype('O')

# %%
df.describe()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18464 entries, 0 to 19236
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                18464 non-null  int64
#  1   Price             18464 non-null  int64
#  2   Levy              18464 non-null  float64
#  3   Manufacturer      18464 non-null  object
#  4   Model             18464 non-null  object
#  5   Prod._year        18464 non-null  int64
#  6   Category          18464 non-null  object
#  7   Leather_interior  18464 non-null  object
#  8   Fuel_type         18464 non-null  object
#  9   Engine_volume     18464 non-null  float64
#  10  Mileage           18464 non-null  int64
#  11  Cylinders         18464 non-null  float64
#  12  Gear_box_type     18464 non-null  object
#  13  Drive_wheels      18464 non-null  object
#  14  Doors             18464 non-null  object
#  15  Wheel             18464 non-null  object
# ...

# %%
df.describe()
# Out:
#                  ID         Price          Levy    Prod._year  Engine_volume  \
# count  1.846400e+04  18464.000000  18464.000000  18464.000000   18464.000000
# mean   4.558722e+07  16304.833351    867.405817   2010.944649       2.297265
# std    8.955997e+05  14701.154152    392.354862      5.599544       0.791919
# min    2.074688e+07     47.000000     87.000000   1939.000000       0.100000
# 25%    4.569980e+07   5500.000000    707.000000   2009.000000       1.800000
# 50%    4.577207e+07  13172.000000    781.000000   2012.000000       2.200000
# 75%    4.580181e+07  21953.000000    917.000000   2014.000000       2.500000
# max    4.581665e+07  83891.000000  11714.000000   2020.000000       7.300000
#
#              Mileage     Cylinders       Airbags       Car_Age
# count   18464.000000  18464.000000  18464.000000  18464.000000
# mean   141205.367688      4.570516      6.573007     15.055351
# std    102620.527240      1.185091      4.322392      5.599544
# ...

# %%
df.to_csv("cleaned_dataset.csv", index=False)

# %%
import os
print(os.getcwd())
# Out:
# d:\USER\Desktop\Study\ING4DS-B\ML\tache 1
